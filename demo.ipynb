# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os

# ensure the NAB dataset is cloned
# https://github.com/numenta/NAB/tree/master/data
if not os.path.isdir('../NAB') or not os.path.isdir('../NAB/data'):
    print('please ensure you clone the NAB data in the parent directory')

# %%
df = pd.read_csv('../NAB/data/artificialWithAnomaly/art_daily_flatmiddle.csv')
df
# Out:
#                 timestamp      value
# 0     2014-04-01 00:00:00 -21.048383
# 1     2014-04-01 00:05:00 -20.295477
# 2     2014-04-01 00:10:00 -18.127229
# 3     2014-04-01 00:15:00 -20.171665
# 4     2014-04-01 00:20:00 -21.223762
# 5     2014-04-01 00:25:00 -19.104491
# 6     2014-04-01 00:30:00 -21.589446
# 7     2014-04-01 00:35:00 -18.945042
# 8     2014-04-01 00:40:00 -18.305893
# 9     2014-04-01 00:45:00 -18.639757
# 10    2014-04-01 00:50:00 -21.348011
# 11    2014-04-01 00:55:00 -19.669224
# 12    2014-04-01 01:00:00 -21.187782
# 13    2014-04-01 01:05:00 -20.124932
# 14    2014-04-01 01:10:00 -19.922236
# 15    2014-04-01 01:15:00 -21.227653
# 16    2014-04-01 01:20:00 -19.693950
# 17    2014-04-01 01:25:00 -21.208131
# 18    2014-04-01 01:30:00 -18.402649
# 19    2014-04-01 01:35:00 -20.545243
# 20    2014-04-01 01:40:00 -20.810348
# 21    2014-04-01 01:45:00 -21.596390
# 22    2014-04-01 01:50:00 -18.897296
# 23    2014-04-01 01:55:00 -20.416880
# ...

# %%
df.plot(x='timestamp', y='value', figsize=(16,12))
